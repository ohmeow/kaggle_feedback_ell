# %% [markdown]
# # Scope

# %% [markdown]
# Ensemble experiments for Feedback Learning models. Read in and prepare OOF files.
#
# Uses MultiOutput models for ensembling.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error

import pandas as pd
import numpy as np
import os, sys, glob
from pathlib import Path

# %% [markdown]
# Adjust the path to the logs here:

# %%
path_logs = Path("./logs")

# %% [markdown]
# The competition metric:

# %%
# | export
def comp_metric_score(preds, targs):
    """This competition is evaluated using "columnwise root mean squared error". Expects numpy arrays."""
    len_target_cols = targs.shape[1]
    score = [0] * len_target_cols
    for i in range(len_target_cols):
        score[i] = np.sqrt(mean_squared_error(preds[:, i], targs[:, i]))
    return np.mean(score)

# %% [markdown]
# # Get OOF data

# %%
files = glob.glob(str(path_logs) + "/*.csv")
files_oof = [f for f in files if "oof" in f]
files = [f for f in files if not "oof" in f]

# %% [markdown]
# Read all the oof files at once:

# %%
oof = pd.concat((pd.read_csv(f).assign(learner_name = f) for f in files_oof))

# %%
oof['learner_name'] = oof['learner_name'].str.replace("logs/oof_", "")

oof[['experiment','run_id']] = oof['learner_name'].str.split('_202', expand=True)
oof[['run_id', 'fold']] = oof['run_id'].str.split('_fold_', expand=True)
oof['run_id'] = oof['run_id'].str.slice(0, -2)

oof['run_id'] = "202" + oof['run_id'].str.replace("", "", regex=True)

oof['learner_name'] = oof['learner_name'].str.replace(".csv", "", regex = False)
oof['fold'] = oof['fold'].str.replace(".csv", "", regex = False).astype('int')
oof['model'] = oof['experiment'] + "_" + oof['run_id']

# %%
oof.shape
# Out:
# (113419, 18)

# %%
oof.head()
# Out:
#    pred_cohesion  pred_syntax  pred_vocabulary  pred_phraseology  \
# 0       2.906250     2.601562         3.029297          2.757812
# 1       3.812500     3.527344         3.777344          3.582031
# 2       2.720703     2.384766         2.763672          2.400391
# 3       3.017578     2.707031         3.136719          2.832031
# 4       3.359375     3.052734         3.410156          3.134766
#
#    pred_grammar  pred_conventions  targ_cohesion  targ_syntax  \
# 0      2.605469          2.761719            3.5          3.5
# 1      3.677734          3.916016            4.0          3.5
# 2      2.267578          2.820312            3.0          2.5
# 3      2.673828          2.923828            4.0          2.5
# 4      3.056641          3.326172            3.5          3.5
#
#    targ_vocabulary  targ_phraseology  targ_grammar  targ_conventions  \
# 0              3.5               3.5           3.0               3.5
# 1              3.5               4.0           4.5               4.0
# 2              2.0               2.0           2.0               3.0
# 3              3.0               3.5           3.0               2.5
# 4              3.0               3.5           3.0               3.0
#
#              run_id  grid_id  \
# 0  2022_11_22_03_26        1
# 1  2022_11_22_03_26        1
# 2  2022_11_22_03_26        1
# 3  2022_11_22_03_26        1
# 4  2022_11_22_03_26        1
#
#                                        learner_name              experiment  \
# 0  blurr_deberta_v3_small_2022_11_22_03_26_1_fold_1  blurr_deberta_v3_small
# 1  blurr_deberta_v3_small_2022_11_22_03_26_1_fold_1  blurr_deberta_v3_small
# 2  blurr_deberta_v3_small_2022_11_22_03_26_1_fold_1  blurr_deberta_v3_small
# 3  blurr_deberta_v3_small_2022_11_22_03_26_1_fold_1  blurr_deberta_v3_small
# 4  blurr_deberta_v3_small_2022_11_22_03_26_1_fold_1  blurr_deberta_v3_small
#
#    fold                                    model
# 0     1  blurr_deberta_v3_small_2022_11_22_03_26
# 1     1  blurr_deberta_v3_small_2022_11_22_03_26
# 2     1  blurr_deberta_v3_small_2022_11_22_03_26
# 3     1  blurr_deberta_v3_small_2022_11_22_03_26
# 4     1  blurr_deberta_v3_small_2022_11_22_03_26

# %% [markdown]
# ### Define ensemble models through `run_id`

# %%
ensemble_run_id = ['2022_11_23_16_10', '2022_11_23_16_18', '2022_11_25_20_33', '2022_11_23_19_08',
'2022_11_23_21_13', '2022_11_23_21_16', '2022_11_25_20_40', '2022_11_25_20_54']

# %% [markdown]
# ### Load the train data folds

# %%
train = pd.read_csv("~/kaggle_feedback_ell/data/clean/train_folds.csv")
train.head(2)
# Out:
#         text_id                                          full_text  cohesion  \
# 0  976E2E05C4EB  Some businesses only work 4 days in the week m...       4.0
# 1  5AA45740A848  Dear, TEACHER_NAME\n\nI think phone policy at ...       3.5
#
#    syntax  vocabulary  phraseology  grammar  conventions  k_fold
# 0     3.0         3.5          3.5      3.0          3.5       4
# 1     2.5         3.5          3.0      3.5          2.5       3

# %% [markdown]
# Prepare OOF for best models

# %%
oof_ensemble = oof[oof.run_id.isin(ensemble_run_id)].drop(['run_id', 'grid_id', 'learner_name', 'experiment'], axis = "columns").reset_index()
oof_ensemble = oof_ensemble.sort_values(['fold', 'index', 'model']).reset_index(drop = True)
oof_ensemble
# Out:
#        index  pred_cohesion  pred_syntax  pred_vocabulary  pred_phraseology  \
# 0          0       1.700195     1.538086         2.048828          1.802734
# 1          0       2.164062     2.009766         2.332031          2.015625
# 2          0       1.724609     1.588867         2.007812          1.796875
# 3          0       1.950195     1.750000         2.201172          1.950195
# 4          0       1.773438     1.750977         2.152344          1.828125
# ...      ...            ...          ...              ...               ...
# 31283    782       3.083984     2.990234         3.183594          3.117188
# 31284    782       3.169922     3.142578         3.123047          3.210938
# 31285    782       3.248047     3.044922         3.283203          3.177734
# 31286    782       3.146484     2.947266         3.082031          3.279297
# 31287    782       3.167969     3.212891         3.406250          3.375000
#
#        pred_grammar  pred_conventions  targ_cohesion  targ_syntax  \
# 0          1.776367          1.657227            2.0          2.0
# 1          1.941406          2.164062            2.0          2.0
# 2          1.785156          1.735352            2.0          2.0
# 3          1.857422          1.984375            2.0          2.0
# 4          1.786133          1.911133            2.0          2.0
# ...             ...               ...            ...          ...
# 31283      3.052734          2.667969            3.5          3.5
# 31284      3.003906          2.792969            3.5          3.5
# 31285      2.996094          2.554688            3.5          3.5
# 31286      3.046875          2.500000            3.5          3.5
# 31287      3.289062          2.429688            3.5          3.5
#
#        targ_vocabulary  targ_phraseology  targ_grammar  targ_conventions  \
# 0                  2.0               2.5           2.0               2.0
# 1                  2.0               2.5           2.0               2.0
# 2                  2.0               2.5           2.0               2.0
# 3                  2.0               2.5           2.0               2.0
# 4                  2.0               2.5           2.0               2.0
# ...                ...               ...           ...               ...
# 31283              4.0               4.0           3.5               3.0
# 31284              4.0               4.0           3.5               3.0
# 31285              4.0               4.0           3.5               3.0
# 31286              4.0               4.0           3.5               3.0
# 31287              4.0               4.0           3.5               3.0
#
#        fold                                    model
# 0         0              bart_large_2022_11_25_20_40
# 1         0     blurr_deberta_large_2022_11_25_20_33
# 2         0   blurr_deberta_v3_base_2022_11_23_16_10
# 3         0  blurr_deberta_v3_large_2022_11_23_16_18
# 4         0  blurr_deberta_v3_small_2022_11_23_19_08
# ...     ...                                      ...
# 31283     4  blurr_deberta_v3_large_2022_11_23_16_18
# 31284     4  blurr_deberta_v3_small_2022_11_23_19_08
# 31285     4    blurr_deberta_xlarge_2022_11_25_20_54
# 31286     4     blurr_roberta_large_2022_11_23_21_13
# 31287     4       xlnet_large_cased_2022_11_23_21_16
#
# [31288 rows x 15 columns]

# %%
oof_ensemble[oof_ensemble.model == "blurr_deberta_v3_base_2022_11_23_16_10"]
# Out:
#        index  pred_cohesion  pred_syntax  pred_vocabulary  pred_phraseology  \
# 2          0       1.724609     1.588867         2.007812          1.796875
# 10         1       2.925781     2.685547         3.074219          2.960938
# 18         2       3.726562     3.644531         3.869141          3.925781
# 26         3       3.478516     3.207031         3.427734          3.345703
# 34         4       3.318359     3.027344         3.302734          3.158203
# ...      ...            ...          ...              ...               ...
# 31250    778       3.332031     3.216797         3.369141          3.414062
# 31258    779       3.431641     3.326172         3.429688          3.480469
# 31266    780       3.330078     3.212891         3.376953          3.447266
# 31274    781       3.199219     3.109375         3.279297          3.343750
# 31282    782       3.121094     3.000000         3.216797          3.226562
#
#        pred_grammar  pred_conventions  targ_cohesion  targ_syntax  \
# 2          1.785156          1.735352            2.0          2.0
# 10         2.923828          2.882812            3.0          3.5
# 18         3.929688          3.835938            3.5          3.5
# 26         2.994141          3.228516            3.5          3.5
# 34         2.968750          3.304688            2.5          2.5
# ...             ...               ...            ...          ...
# 31250      3.146484          3.263672            2.5          3.5
# 31258      3.238281          3.431641            4.0          3.5
# 31266      3.158203          3.259766            3.5          3.5
# 31274      3.205078          3.185547            3.5          3.0
# 31282      2.939453          2.945312            3.5          3.5
#
#        targ_vocabulary  targ_phraseology  targ_grammar  targ_conventions  \
# 2                  2.0               2.5           2.0               2.0
# 10                 3.0               3.0           4.0               3.5
# 18                 4.5               4.0           4.0               4.5
# 26                 3.0               2.5           2.5               3.0
# 34                 3.0               3.0           3.0               2.5
# ...                ...               ...           ...               ...
# 31250              3.0               3.0           2.5               3.0
# 31258              3.5               3.5           3.0               3.0
# 31266              4.0               3.0           2.5               3.5
# 31274              3.0               3.5           3.5               3.0
# 31282              4.0               4.0           3.5               3.0
#
#        fold                                   model
# 2         0  blurr_deberta_v3_base_2022_11_23_16_10
# 10        0  blurr_deberta_v3_base_2022_11_23_16_10
# 18        0  blurr_deberta_v3_base_2022_11_23_16_10
# 26        0  blurr_deberta_v3_base_2022_11_23_16_10
# 34        0  blurr_deberta_v3_base_2022_11_23_16_10
# ...     ...                                     ...
# 31250     4  blurr_deberta_v3_base_2022_11_23_16_10
# 31258     4  blurr_deberta_v3_base_2022_11_23_16_10
# 31266     4  blurr_deberta_v3_base_2022_11_23_16_10
# 31274     4  blurr_deberta_v3_base_2022_11_23_16_10
# 31282     4  blurr_deberta_v3_base_2022_11_23_16_10
#
# [3911 rows x 15 columns]

# %% [markdown]
# Scoring example for single oof & fold - also sanity check as QA for building `oof_ensemble_train`:

# %%
check = oof_ensemble[(oof_ensemble.model == "blurr_deberta_v3_base_2022_11_23_16_10") & (oof_ensemble.fold == 0)].reset_index(drop = True)
check_preds = check.loc[:, [col for col in check if col.startswith("pred_")]]
check_targs = check.loc[:, [col for col in check if col.startswith("targ_")]]
comp_metric_score(np.array(check_preds), np.array(check_targs))
# Out:
# 0.47893095671523817

# %%
check_preds
# Out:
#      pred_cohesion  pred_syntax  pred_vocabulary  pred_phraseology  \
# 0         1.724609     1.588867         2.007812          1.796875
# 1         2.925781     2.685547         3.074219          2.960938
# 2         3.726562     3.644531         3.869141          3.925781
# 3         3.478516     3.207031         3.427734          3.345703
# 4         3.318359     3.027344         3.302734          3.158203
# ..             ...          ...              ...               ...
# 777       3.980469     3.750000         3.927734          3.890625
# 778       3.041016     2.650391         3.025391          2.722656
# 779       3.134766     3.001953         3.220703          3.187500
# 780       3.667969     3.515625         3.640625          3.679688
# 781       3.736328     3.458984         3.673828          3.552734
#
#      pred_grammar  pred_conventions
# 0        1.785156          1.735352
# 1        2.923828          2.882812
# 2        3.929688          3.835938
# 3        2.994141          3.228516
# 4        2.968750          3.304688
# ..            ...               ...
# 777      3.523438          3.863281
# 778      2.410156          2.951172
# 779      3.263672          3.283203
# 780      3.580078          3.628906
# 781      3.326172          3.816406
#
# [782 rows x 6 columns]

# %%
np.sqrt(mean_squared_error(check_preds.iloc[:, 0], check_targs.iloc[:, 0]))
# Out:
# 0.5131803667982215

# %% [markdown]
# Preparing the restructure:

# %%
oof_cols = oof_ensemble.model.unique()
oof_cols
# Out:
# array(['bart_large_2022_11_25_20_40',
#        'blurr_deberta_large_2022_11_25_20_33',
#        'blurr_deberta_v3_base_2022_11_23_16_10',
#        'blurr_deberta_v3_large_2022_11_23_16_18',
#        'blurr_deberta_v3_small_2022_11_23_19_08',
#        'blurr_deberta_xlarge_2022_11_25_20_54',
#        'blurr_roberta_large_2022_11_23_21_13',
#        'xlnet_large_cased_2022_11_23_21_16'], dtype=object)

# %%
oof_ensemble.head(5)
# Out:
#    index  pred_cohesion  pred_syntax  pred_vocabulary  pred_phraseology  \
# 0      0       1.700195     1.538086         2.048828          1.802734
# 1      0       2.164062     2.009766         2.332031          2.015625
# 2      0       1.724609     1.588867         2.007812          1.796875
# 3      0       1.950195     1.750000         2.201172          1.950195
# 4      0       1.773438     1.750977         2.152344          1.828125
#
#    pred_grammar  pred_conventions  targ_cohesion  targ_syntax  \
# 0      1.776367          1.657227            2.0          2.0
# 1      1.941406          2.164062            2.0          2.0
# 2      1.785156          1.735352            2.0          2.0
# 3      1.857422          1.984375            2.0          2.0
# 4      1.786133          1.911133            2.0          2.0
#
#    targ_vocabulary  targ_phraseology  targ_grammar  targ_conventions  fold  \
# 0              2.0               2.5           2.0               2.0     0
# 1              2.0               2.5           2.0               2.0     0
# 2              2.0               2.5           2.0               2.0     0
# 3              2.0               2.5           2.0               2.0     0
# 4              2.0               2.5           2.0               2.0     0
#
#                                      model
# 0              bart_large_2022_11_25_20_40
# 1     blurr_deberta_large_2022_11_25_20_33
# 2   blurr_deberta_v3_base_2022_11_23_16_10
# 3  blurr_deberta_v3_large_2022_11_23_16_18
# 4  blurr_deberta_v3_small_2022_11_23_19_08

# %% [markdown]
# The target columns

# %%
targ_cols = list(oof_ensemble.columns[oof_ensemble.columns.str.startswith('targ_')])
targ_cols
# Out:
# ['targ_cohesion',
#  'targ_syntax',
#  'targ_vocabulary',
#  'targ_phraseology',
#  'targ_grammar',
#  'targ_conventions']

# %% [markdown]
# Pivot to wider: we'll now have each model's predictions as a df column:

# %%
foo = oof_ensemble.loc[:, ~oof_ensemble.columns.str.startswith('targ_')]
foo = foo.pivot(index = ["index", "fold"], columns="model").reset_index().reset_index(drop = True)
foo.columns = ['-'.join(col).strip() for col in foo.columns.values]
foo = foo.rename_axis(None, axis=1).rename(columns = {'fold-': 'fold', 'index-': 'index'})

# %%
foo
# Out:
#       index  fold  pred_cohesion-bart_large_2022_11_25_20_40  \
# 0         0     0                                   1.700195
# 1         0     1                                   3.001953
# 2         0     2                                   3.101562
# 3         0     3                                   2.505859
# 4         0     4                                   2.714844
# ...     ...   ...                                        ...
# 3906    781     1                                   2.257812
# 3907    781     2                                   4.027344
# 3908    781     3                                   2.640625
# 3909    781     4                                   3.119141
# 3910    782     4                                   3.486328
#
#       pred_cohesion-blurr_deberta_large_2022_11_25_20_33  \
# 0                                              2.164062
# 1                                              3.177734
# 2                                              3.091797
# 3                                              3.171875
# 4                                              2.386719
# ...                                                 ...
# 3906                                           2.371094
# 3907                                           3.832031
# 3908                                           2.742188
# 3909                                           3.066406
# 3910                                           3.052734
#
#       pred_cohesion-blurr_deberta_v3_base_2022_11_23_16_10  \
# 0                                              1.724609
# 1                                              2.890625
# 2                                              3.173828
# 3                                              2.767578
# 4                                              2.507812
# ...                                                 ...
# 3906                                           2.417969
# 3907                                           3.472656
# 3908                                           2.966797
# 3909                                           3.199219
# 3910                                           3.121094
#
#       pred_cohesion-blurr_deberta_v3_large_2022_11_23_16_18  \
# 0                                              1.950195
# 1                                              3.208984
# 2                                              3.289062
# 3                                              3.070312
# 4                                              2.603516
# ...                                                 ...
# 3906                                           2.429688
# 3907                                           3.523438
# 3908                                           3.082031
# 3909                                           3.164062
# 3910                                           3.083984
#
#       pred_cohesion-blurr_deberta_v3_small_2022_11_23_19_08  \
# 0                                              1.773438
# 1                                              2.855469
# 2                                              3.121094
# 3                                              2.984375
# 4                                              2.490234
# ...                                                 ...
# 3906                                           2.525391
# 3907                                           3.521484
# 3908                                           3.140625
# 3909                                           3.138672
# 3910                                           3.169922
#
#       pred_cohesion-blurr_deberta_xlarge_2022_11_25_20_54  \
# 0                                              2.570312
# 1                                              3.503906
# 2                                              3.156250
# 3                                              2.802734
# 4                                              2.626953
# ...                                                 ...
# 3906                                           2.423828
# 3907                                           3.578125
# 3908                                           3.115234
# 3909                                           3.330078
# 3910                                           3.248047
#
#       pred_cohesion-blurr_roberta_large_2022_11_23_21_13  \
# 0                                              1.735352
# 1                                              3.304688
# 2                                              3.185547
# 3                                              2.718750
# 4                                              2.894531
# ...                                                 ...
# 3906                                           2.509766
# 3907                                           3.654297
# 3908                                           2.960938
# 3909                                           2.826172
# 3910                                           3.146484
#
#       pred_cohesion-xlnet_large_cased_2022_11_23_21_16  ...  \
# 0                                             1.591797  ...
# 1                                             3.804688  ...
# 2                                             3.052734  ...
# 3                                             2.818359  ...
# 4                                             2.707031  ...
# ...                                                ...  ...
# 3906                                          2.357422  ...
# 3907                                          3.583984  ...
# 3908                                          2.886719  ...
# 3909                                          3.136719  ...
# 3910                                          3.167969  ...
#
#       pred_grammar-blurr_roberta_large_2022_11_23_21_13  \
# 0                                              1.788086
# 1                                              3.554688
# 2                                              3.269531
# 3                                              3.419922
# 4                                              2.275391
# ...                                                 ...
# 3906                                           2.152344
# 3907                                           3.589844
# 3908                                           2.859375
# 3909                                           3.115234
# 3910                                           3.046875
#
#       pred_grammar-xlnet_large_cased_2022_11_23_21_16  \
# 0                                            1.742188
# 1                                            3.312500
# 2                                            3.505859
# 3                                            3.529297
# 4                                            2.275391
# ...                                               ...
# 3906                                         2.212891
# 3907                                         3.322266
# 3908                                         3.052734
# 3909                                         3.308594
# 3910                                         3.289062
#
#       pred_conventions-bart_large_2022_11_25_20_40  \
# 0                                         1.657227
# 1                                         2.791016
# 2                                         3.222656
# 3                                         3.140625
# 4                                         2.214844
# ...                                            ...
# 3906                                      2.521484
# 3907                                      3.425781
# 3908                                      3.181641
# 3909                                      3.083984
# 3910                                      3.000000
#
#       pred_conventions-blurr_deberta_large_2022_11_25_20_33  \
# 0                                              2.164062
# 1                                              2.910156
# 2                                              2.892578
# 3                                              2.986328
# 4                                              2.087891
# ...                                                 ...
# 3906                                           2.384766
# 3907                                           3.316406
# 3908                                           3.291016
# 3909                                           3.054688
# 3910                                           2.535156
#
#       pred_conventions-blurr_deberta_v3_base_2022_11_23_16_10  \
# 0                                              1.735352
# 1                                              2.726562
# 2                                              3.091797
# 3                                              2.980469
# 4                                              2.357422
# ...                                                 ...
# 3906                                           2.474609
# 3907                                           3.369141
# 3908                                           2.982422
# 3909                                           3.185547
# 3910                                           2.945312
#
#       pred_conventions-blurr_deberta_v3_large_2022_11_23_16_18  \
# 0                                              1.984375
# 1                                              2.925781
# 2                                              3.125000
# 3                                              3.308594
# 4                                              2.304688
# ...                                                 ...
# 3906                                           2.658203
# 3907                                           3.376953
# 3908                                           3.273438
# 3909                                           3.064453
# 3910                                           2.667969
#
#       pred_conventions-blurr_deberta_v3_small_2022_11_23_19_08  \
# 0                                              1.911133
# 1                                              2.730469
# 2                                              2.976562
# 3                                              2.951172
# 4                                              2.230469
# ...                                                 ...
# 3906                                           2.595703
# 3907                                           3.357422
# 3908                                           3.056641
# 3909                                           3.042969
# 3910                                           2.792969
#
#       pred_conventions-blurr_deberta_xlarge_2022_11_25_20_54  \
# 0                                              2.439453
# 1                                              2.871094
# 2                                              3.042969
# 3                                              2.710938
# 4                                              2.035156
# ...                                                 ...
# 3906                                           2.470703
# 3907                                           3.298828
# 3908                                           3.228516
# 3909                                           3.304688
# 3910                                           2.554688
#
#       pred_conventions-blurr_roberta_large_2022_11_23_21_13  \
# 0                                              1.679688
# 1                                              2.974609
# 2                                              3.210938
# 3                                              2.763672
# 4                                              2.105469
# ...                                                 ...
# 3906                                           2.453125
# 3907                                           3.421875
# 3908                                           3.109375
# 3909                                           2.808594
# 3910                                           2.500000
#
#       pred_conventions-xlnet_large_cased_2022_11_23_21_16
# 0                                              1.798828
# 1                                              2.935547
# 2                                              3.287109
# 3                                              3.289062
# 4                                              2.123047
# ...                                                 ...
# 3906                                           2.478516
# 3907                                           3.273438
# 3908                                           3.382812
# 3909                                           2.974609
# 3910                                           2.429688
#
# [3911 rows x 50 columns]

# %% [markdown]
# Sanity checks:

# %%
foobar = oof_ensemble.loc[oof_ensemble.model == "xlnet_large_cased_2022_11_23_21_16", ~oof_ensemble.columns.str.startswith('targ_')].reset_index(drop = True)
foobar[foobar.fold == 0]
# Out:
#      index  pred_cohesion  pred_syntax  pred_vocabulary  pred_phraseology  \
# 0        0       1.591797     1.541992         2.080078          1.727539
# 1        1       3.048828     2.986328         3.289062          3.347656
# 2        2       3.587891     3.562500         3.824219          3.880859
# 3        3       3.771484     3.275391         3.546875          3.396484
# 4        4       3.410156     3.056641         3.316406          3.042969
# ..     ...            ...          ...              ...               ...
# 777    777       3.974609     3.646484         3.986328          3.769531
# 778    778       3.263672     3.052734         3.412109          3.132812
# 779    779       3.111328     3.177734         3.396484          3.277344
# 780    780       3.695312     3.488281         3.562500          3.603516
# 781    781       3.902344     3.595703         3.769531          3.564453
#
#      pred_grammar  pred_conventions  fold                               model
# 0        1.742188          1.798828     0  xlnet_large_cased_2022_11_23_21_16
# 1        3.376953          3.392578     0  xlnet_large_cased_2022_11_23_21_16
# 2        3.779297          3.992188     0  xlnet_large_cased_2022_11_23_21_16
# 3        3.072266          3.359375     0  xlnet_large_cased_2022_11_23_21_16
# 4        2.966797          3.400391     0  xlnet_large_cased_2022_11_23_21_16
# ..            ...               ...   ...                                 ...
# 777      3.570312          4.085938     0  xlnet_large_cased_2022_11_23_21_16
# 778      2.925781          3.496094     0  xlnet_large_cased_2022_11_23_21_16
# 779      3.486328          3.765625     0  xlnet_large_cased_2022_11_23_21_16
# 780      3.699219          3.658203     0  xlnet_large_cased_2022_11_23_21_16
# 781      3.421875          4.019531     0  xlnet_large_cased_2022_11_23_21_16
#
# [782 rows x 9 columns]

# %%
foobar = oof_ensemble.loc[oof_ensemble.model == "blurr_deberta_v3_base_2022_11_23_16_10", ~oof_ensemble.columns.str.startswith('targ_')].reset_index(drop = True)
foobar[foobar.fold == 0]
# Out:
#      index  pred_cohesion  pred_syntax  pred_vocabulary  pred_phraseology  \
# 0        0       1.724609     1.588867         2.007812          1.796875
# 1        1       2.925781     2.685547         3.074219          2.960938
# 2        2       3.726562     3.644531         3.869141          3.925781
# 3        3       3.478516     3.207031         3.427734          3.345703
# 4        4       3.318359     3.027344         3.302734          3.158203
# ..     ...            ...          ...              ...               ...
# 777    777       3.980469     3.750000         3.927734          3.890625
# 778    778       3.041016     2.650391         3.025391          2.722656
# 779    779       3.134766     3.001953         3.220703          3.187500
# 780    780       3.667969     3.515625         3.640625          3.679688
# 781    781       3.736328     3.458984         3.673828          3.552734
#
#      pred_grammar  pred_conventions  fold  \
# 0        1.785156          1.735352     0
# 1        2.923828          2.882812     0
# 2        3.929688          3.835938     0
# 3        2.994141          3.228516     0
# 4        2.968750          3.304688     0
# ..            ...               ...   ...
# 777      3.523438          3.863281     0
# 778      2.410156          2.951172     0
# 779      3.263672          3.283203     0
# 780      3.580078          3.628906     0
# 781      3.326172          3.816406     0
#
#                                       model
# 0    blurr_deberta_v3_base_2022_11_23_16_10
# 1    blurr_deberta_v3_base_2022_11_23_16_10
# 2    blurr_deberta_v3_base_2022_11_23_16_10
# 3    blurr_deberta_v3_base_2022_11_23_16_10
# 4    blurr_deberta_v3_base_2022_11_23_16_10
# ..                                      ...
# 777  blurr_deberta_v3_base_2022_11_23_16_10
# 778  blurr_deberta_v3_base_2022_11_23_16_10
# 779  blurr_deberta_v3_base_2022_11_23_16_10
# 780  blurr_deberta_v3_base_2022_11_23_16_10
# 781  blurr_deberta_v3_base_2022_11_23_16_10
#
# [782 rows x 9 columns]

# %%
check
# Out:
#      index  pred_cohesion  pred_syntax  pred_vocabulary  pred_phraseology  \
# 0        0       1.724609     1.588867         2.007812          1.796875
# 1        1       2.925781     2.685547         3.074219          2.960938
# 2        2       3.726562     3.644531         3.869141          3.925781
# 3        3       3.478516     3.207031         3.427734          3.345703
# 4        4       3.318359     3.027344         3.302734          3.158203
# ..     ...            ...          ...              ...               ...
# 777    777       3.980469     3.750000         3.927734          3.890625
# 778    778       3.041016     2.650391         3.025391          2.722656
# 779    779       3.134766     3.001953         3.220703          3.187500
# 780    780       3.667969     3.515625         3.640625          3.679688
# 781    781       3.736328     3.458984         3.673828          3.552734
#
#      pred_grammar  pred_conventions  targ_cohesion  targ_syntax  \
# 0        1.785156          1.735352            2.0          2.0
# 1        2.923828          2.882812            3.0          3.5
# 2        3.929688          3.835938            3.5          3.5
# 3        2.994141          3.228516            3.5          3.5
# 4        2.968750          3.304688            2.5          2.5
# ..            ...               ...            ...          ...
# 777      3.523438          3.863281            4.0          4.5
# 778      2.410156          2.951172            2.5          2.5
# 779      3.263672          3.283203            3.0          3.0
# 780      3.580078          3.628906            3.5          3.0
# 781      3.326172          3.816406            3.5          4.0
#
#      targ_vocabulary  targ_phraseology  targ_grammar  targ_conventions  fold  \
# 0                2.0               2.5           2.0               2.0     0
# 1                3.0               3.0           4.0               3.5     0
# 2                4.5               4.0           4.0               4.5     0
# 3                3.0               2.5           2.5               3.0     0
# 4                3.0               3.0           3.0               2.5     0
# ..               ...               ...           ...               ...   ...
# 777              4.5               4.0           4.5               4.5     0
# 778              2.5               3.0           2.5               3.5     0
# 779              3.0               2.5           3.0               4.0     0
# 780              3.5               3.5           4.0               3.0     0
# 781              3.5               3.5           3.0               3.5     0
#
#                                       model
# 0    blurr_deberta_v3_base_2022_11_23_16_10
# 1    blurr_deberta_v3_base_2022_11_23_16_10
# 2    blurr_deberta_v3_base_2022_11_23_16_10
# 3    blurr_deberta_v3_base_2022_11_23_16_10
# 4    blurr_deberta_v3_base_2022_11_23_16_10
# ..                                      ...
# 777  blurr_deberta_v3_base_2022_11_23_16_10
# 778  blurr_deberta_v3_base_2022_11_23_16_10
# 779  blurr_deberta_v3_base_2022_11_23_16_10
# 780  blurr_deberta_v3_base_2022_11_23_16_10
# 781  blurr_deberta_v3_base_2022_11_23_16_10
#
# [782 rows x 15 columns]

# %% [markdown]
# The targets to join back onto:

# %%
bar = oof_ensemble.loc[oof_ensemble.model == oof_ensemble.model[0], ['fold', 'index'] + targ_cols].reset_index(drop = True) # drop(columns = ['fold', 'index'])
bar
# Out:
#       fold  index  targ_cohesion  targ_syntax  targ_vocabulary  \
# 0        0      0            2.0          2.0              2.0
# 1        0      1            3.0          3.5              3.0
# 2        0      2            3.5          3.5              4.5
# 3        0      3            3.5          3.5              3.0
# 4        0      4            2.5          2.5              3.0
# ...    ...    ...            ...          ...              ...
# 3906     4    778            2.5          3.5              3.0
# 3907     4    779            4.0          3.5              3.5
# 3908     4    780            3.5          3.5              4.0
# 3909     4    781            3.5          3.0              3.0
# 3910     4    782            3.5          3.5              4.0
#
#       targ_phraseology  targ_grammar  targ_conventions
# 0                  2.5           2.0               2.0
# 1                  3.0           4.0               3.5
# 2                  4.0           4.0               4.5
# 3                  2.5           2.5               3.0
# 4                  3.0           3.0               2.5
# ...                ...           ...               ...
# 3906               3.0           2.5               3.0
# 3907               3.5           3.0               3.0
# 3908               3.0           2.5               3.5
# 3909               3.5           3.5               3.0
# 3910               4.0           3.5               3.0
#
# [3911 rows x 8 columns]

# %% [markdown]
# Sanity checks:

# %%
bar[bar.fold == 0]
# Out:
#      fold  index  targ_cohesion  targ_syntax  targ_vocabulary  \
# 0       0      0            2.0          2.0              2.0
# 1       0      1            3.0          3.5              3.0
# 2       0      2            3.5          3.5              4.5
# 3       0      3            3.5          3.5              3.0
# 4       0      4            2.5          2.5              3.0
# ..    ...    ...            ...          ...              ...
# 777     0    777            4.0          4.5              4.5
# 778     0    778            2.5          2.5              2.5
# 779     0    779            3.0          3.0              3.0
# 780     0    780            3.5          3.0              3.5
# 781     0    781            3.5          4.0              3.5
#
#      targ_phraseology  targ_grammar  targ_conventions
# 0                 2.5           2.0               2.0
# 1                 3.0           4.0               3.5
# 2                 4.0           4.0               4.5
# 3                 2.5           2.5               3.0
# 4                 3.0           3.0               2.5
# ..                ...           ...               ...
# 777               4.0           4.5               4.5
# 778               3.0           2.5               3.5
# 779               2.5           3.0               4.0
# 780               3.5           4.0               3.0
# 781               3.5           3.0               3.5
#
# [782 rows x 8 columns]

# %%
check
# Out:
#      index  pred_cohesion  pred_syntax  pred_vocabulary  pred_phraseology  \
# 0        0       1.724609     1.588867         2.007812          1.796875
# 1        1       2.925781     2.685547         3.074219          2.960938
# 2        2       3.726562     3.644531         3.869141          3.925781
# 3        3       3.478516     3.207031         3.427734          3.345703
# 4        4       3.318359     3.027344         3.302734          3.158203
# ..     ...            ...          ...              ...               ...
# 777    777       3.980469     3.750000         3.927734          3.890625
# 778    778       3.041016     2.650391         3.025391          2.722656
# 779    779       3.134766     3.001953         3.220703          3.187500
# 780    780       3.667969     3.515625         3.640625          3.679688
# 781    781       3.736328     3.458984         3.673828          3.552734
#
#      pred_grammar  pred_conventions  targ_cohesion  targ_syntax  \
# 0        1.785156          1.735352            2.0          2.0
# 1        2.923828          2.882812            3.0          3.5
# 2        3.929688          3.835938            3.5          3.5
# 3        2.994141          3.228516            3.5          3.5
# 4        2.968750          3.304688            2.5          2.5
# ..            ...               ...            ...          ...
# 777      3.523438          3.863281            4.0          4.5
# 778      2.410156          2.951172            2.5          2.5
# 779      3.263672          3.283203            3.0          3.0
# 780      3.580078          3.628906            3.5          3.0
# 781      3.326172          3.816406            3.5          4.0
#
#      targ_vocabulary  targ_phraseology  targ_grammar  targ_conventions  fold  \
# 0                2.0               2.5           2.0               2.0     0
# 1                3.0               3.0           4.0               3.5     0
# 2                4.5               4.0           4.0               4.5     0
# 3                3.0               2.5           2.5               3.0     0
# 4                3.0               3.0           3.0               2.5     0
# ..               ...               ...           ...               ...   ...
# 777              4.5               4.0           4.5               4.5     0
# 778              2.5               3.0           2.5               3.5     0
# 779              3.0               2.5           3.0               4.0     0
# 780              3.5               3.5           4.0               3.0     0
# 781              3.5               3.5           3.0               3.5     0
#
#                                       model
# 0    blurr_deberta_v3_base_2022_11_23_16_10
# 1    blurr_deberta_v3_base_2022_11_23_16_10
# 2    blurr_deberta_v3_base_2022_11_23_16_10
# 3    blurr_deberta_v3_base_2022_11_23_16_10
# 4    blurr_deberta_v3_base_2022_11_23_16_10
# ..                                      ...
# 777  blurr_deberta_v3_base_2022_11_23_16_10
# 778  blurr_deberta_v3_base_2022_11_23_16_10
# 779  blurr_deberta_v3_base_2022_11_23_16_10
# 780  blurr_deberta_v3_base_2022_11_23_16_10
# 781  blurr_deberta_v3_base_2022_11_23_16_10
#
# [782 rows x 15 columns]

# %%
oof_ensemble_train = foo.merge(bar, how = "left", on = ['fold', 'index'])

# %% [markdown]
# Everything is together in this combined df now:

# %%
oof_ensemble_train
# Out:
#       index  fold  pred_cohesion-bart_large_2022_11_25_20_40  \
# 0         0     0                                   1.700195
# 1         0     1                                   3.001953
# 2         0     2                                   3.101562
# 3         0     3                                   2.505859
# 4         0     4                                   2.714844
# ...     ...   ...                                        ...
# 3906    781     1                                   2.257812
# 3907    781     2                                   4.027344
# 3908    781     3                                   2.640625
# 3909    781     4                                   3.119141
# 3910    782     4                                   3.486328
#
#       pred_cohesion-blurr_deberta_large_2022_11_25_20_33  \
# 0                                              2.164062
# 1                                              3.177734
# 2                                              3.091797
# 3                                              3.171875
# 4                                              2.386719
# ...                                                 ...
# 3906                                           2.371094
# 3907                                           3.832031
# 3908                                           2.742188
# 3909                                           3.066406
# 3910                                           3.052734
#
#       pred_cohesion-blurr_deberta_v3_base_2022_11_23_16_10  \
# 0                                              1.724609
# 1                                              2.890625
# 2                                              3.173828
# 3                                              2.767578
# 4                                              2.507812
# ...                                                 ...
# 3906                                           2.417969
# 3907                                           3.472656
# 3908                                           2.966797
# 3909                                           3.199219
# 3910                                           3.121094
#
#       pred_cohesion-blurr_deberta_v3_large_2022_11_23_16_18  \
# 0                                              1.950195
# 1                                              3.208984
# 2                                              3.289062
# 3                                              3.070312
# 4                                              2.603516
# ...                                                 ...
# 3906                                           2.429688
# 3907                                           3.523438
# 3908                                           3.082031
# 3909                                           3.164062
# 3910                                           3.083984
#
#       pred_cohesion-blurr_deberta_v3_small_2022_11_23_19_08  \
# 0                                              1.773438
# 1                                              2.855469
# 2                                              3.121094
# 3                                              2.984375
# 4                                              2.490234
# ...                                                 ...
# 3906                                           2.525391
# 3907                                           3.521484
# 3908                                           3.140625
# 3909                                           3.138672
# 3910                                           3.169922
#
#       pred_cohesion-blurr_deberta_xlarge_2022_11_25_20_54  \
# 0                                              2.570312
# 1                                              3.503906
# 2                                              3.156250
# 3                                              2.802734
# 4                                              2.626953
# ...                                                 ...
# 3906                                           2.423828
# 3907                                           3.578125
# 3908                                           3.115234
# 3909                                           3.330078
# 3910                                           3.248047
#
#       pred_cohesion-blurr_roberta_large_2022_11_23_21_13  \
# 0                                              1.735352
# 1                                              3.304688
# 2                                              3.185547
# 3                                              2.718750
# 4                                              2.894531
# ...                                                 ...
# 3906                                           2.509766
# 3907                                           3.654297
# 3908                                           2.960938
# 3909                                           2.826172
# 3910                                           3.146484
#
#       pred_cohesion-xlnet_large_cased_2022_11_23_21_16  ...  \
# 0                                             1.591797  ...
# 1                                             3.804688  ...
# 2                                             3.052734  ...
# 3                                             2.818359  ...
# 4                                             2.707031  ...
# ...                                                ...  ...
# 3906                                          2.357422  ...
# 3907                                          3.583984  ...
# 3908                                          2.886719  ...
# 3909                                          3.136719  ...
# 3910                                          3.167969  ...
#
#       pred_conventions-blurr_deberta_v3_small_2022_11_23_19_08  \
# 0                                              1.911133
# 1                                              2.730469
# 2                                              2.976562
# 3                                              2.951172
# 4                                              2.230469
# ...                                                 ...
# 3906                                           2.595703
# 3907                                           3.357422
# 3908                                           3.056641
# 3909                                           3.042969
# 3910                                           2.792969
#
#       pred_conventions-blurr_deberta_xlarge_2022_11_25_20_54  \
# 0                                              2.439453
# 1                                              2.871094
# 2                                              3.042969
# 3                                              2.710938
# 4                                              2.035156
# ...                                                 ...
# 3906                                           2.470703
# 3907                                           3.298828
# 3908                                           3.228516
# 3909                                           3.304688
# 3910                                           2.554688
#
#       pred_conventions-blurr_roberta_large_2022_11_23_21_13  \
# 0                                              1.679688
# 1                                              2.974609
# 2                                              3.210938
# 3                                              2.763672
# 4                                              2.105469
# ...                                                 ...
# 3906                                           2.453125
# 3907                                           3.421875
# 3908                                           3.109375
# 3909                                           2.808594
# 3910                                           2.500000
#
#       pred_conventions-xlnet_large_cased_2022_11_23_21_16  targ_cohesion  \
# 0                                              1.798828              2.0
# 1                                              2.935547              3.5
# 2                                              3.287109              3.0
# 3                                              3.289062              3.0
# 4                                              2.123047              3.0
# ...                                                 ...              ...
# 3906                                           2.478516              2.5
# 3907                                           3.273438              3.0
# 3908                                           3.382812              2.5
# 3909                                           2.974609              3.5
# 3910                                           2.429688              3.5
#
#       targ_syntax  targ_vocabulary  targ_phraseology  targ_grammar  \
# 0             2.0              2.0               2.5           2.0
# 1             3.5              3.5               3.5           3.0
# 2             3.0              3.5               3.0           3.5
# 3             2.0              3.0               3.5           3.0
# 4             2.5              2.5               2.0           2.0
# ...           ...              ...               ...           ...
# 3906          2.0              2.5               2.0           2.0
# 3907          3.5              3.5               3.0           3.5
# 3908          2.5              2.5               2.0           2.0
# 3909          3.0              3.0               3.5           3.5
# 3910          3.5              4.0               4.0           3.5
#
#       targ_conventions
# 0                  2.0
# 1                  3.5
# 2                  3.5
# 3                  3.0
# 4                  2.0
# ...                ...
# 3906               2.5
# 3907               3.0
# 3908               2.0
# 3909               3.0
# 3910               3.0
#
# [3911 rows x 56 columns]

# %% [markdown]
# Final sanity check:

# %%
np.sqrt(mean_squared_error(
    oof_ensemble_train.loc[oof_ensemble_train.fold == 0, "pred_cohesion-blurr_deberta_v3_base_2022_11_23_16_10"],
    oof_ensemble_train.loc[oof_ensemble_train.fold == 0, "targ_cohesion"]
    ))
# Out:
# 0.5131803667982215

# %%
np.sqrt(mean_squared_error(check_preds.iloc[:, 0], check_targs.iloc[:, 0]))
# Out:
# 0.5131803667982215

# %%
oof_ensemble_train.to_csv("oof_ensemble_train.csv", index = False)

# %% [markdown]
# # Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor

from sklearn.multioutput import MultiOutputRegressor

import lightgbm as lgb

from joblib import dump, load

# %% [markdown]
# ### Simple example with multi-output regressor:

# %%
train_oof = oof_ensemble_train[oof_ensemble_train.fold != 0]
valid_oof = oof_ensemble_train[oof_ensemble_train.fold == 0]

# %%
X = train_oof.drop(columns = ['fold'] + targ_cols).values
y = train_oof.loc[:, targ_cols].values

# %%
X.shape, y.shape
# Out:
# ((3129, 49), (3129, 6))

# %%
mod = MultiOutputRegressor(Ridge(random_state=4321))
mod.fit(X, y)
# Out:
# MultiOutputRegressor(estimator=Ridge(random_state=4321))

# %%
y_pred = mod.predict(X)

# %%
y_pred.shape
# Out:
# (3129, 6)

# %%
comp_metric_score(y, y_pred)
# Out:
# 0.44352825852967975

# %% [markdown]
# In a loop:

# %%
oof_pred = pd.DataFrame()
oof_scores = []

for i in range(5):
    train_oof = oof_ensemble_train[oof_ensemble_train.fold != i]
    valid_oof = oof_ensemble_train[oof_ensemble_train.fold == i]

    X = train_oof.drop(columns = ['fold'] + targ_cols).values
    y = train_oof.loc[:, targ_cols].values
    
    X_valid = valid_oof.drop(columns = ['fold'] + targ_cols).values
    y_valid = valid_oof.loc[:, targ_cols].values

    mod = MultiOutputRegressor(Ridge(random_state=4321))
    mod.fit(X, y)

    dump(mod, f'mod_ridge_v1_fold_{i}.joblib')    

    y_pred = mod.predict(X_valid)
    oof_scores.append(comp_metric_score(y_valid, y_pred))
    

np.mean(oof_scores), oof_scores
# Out:
# (0.4582612859123323,
#  [0.4702346843655463,
#   0.4547056870643935,
#   0.44685136146328147,
#   0.4635779963463332,
#   0.45593670032210704])

# %% [markdown]
# That's a start. With Ridge Regression only.

# %% [markdown]
# ### LightGBM

# %% [markdown]
# Using default params to demonstrate passing of parameters:

# %%
params = {'n_estimators': 100, 'learning_rate': 0.1}

# %%
oof_pred = pd.DataFrame()
oof_scores = []

for i in range(5):
    train_oof = oof_ensemble_train[oof_ensemble_train.fold != i]
    valid_oof = oof_ensemble_train[oof_ensemble_train.fold == i]

    X = train_oof.drop(columns = ['fold'] + targ_cols).values
    y = train_oof.loc[:, targ_cols].values

    X_valid = valid_oof.drop(columns = ['fold'] + targ_cols).values
    y_valid = valid_oof.loc[:, targ_cols].values

    mod = MultiOutputRegressor(lgb.LGBMRegressor(random_state=4321, **params))
    mod.fit(X, y)
    
    dump(mod, f'mod_lightgbm_v1_fold_{i}.joblib')

    y_pred = mod.predict(X_valid)
    oof_scores.append(comp_metric_score(y_valid, y_pred))
    

np.mean(oof_scores), oof_scores
# Out:
# (0.47194744454122783,
#  [0.4819029230648639,
#   0.4715829305227279,
#   0.4614212170389221,
#   0.47345244943691006,
#   0.4713777026427153])

# %% [markdown]
# Alright, we get reasonable results. Could do some tuning from here.
